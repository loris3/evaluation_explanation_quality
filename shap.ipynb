# %%
text_human = u"It often happens that while working on one project, you need to use another project from within it. Perhaps it’s a library that a third party developed or that you’re developing separately and using in multiple parent projects. A common issue arises in these scenarios: you want to be able to treat the two projects as separate yet still be able to use one from within the other."
text_gpt2 = u"Good news for The Logan Society members [kiss_off/Stephen] and their allies. There's a new news article cited above that says we can rest assured as of now that the project is not dead, but will instead be put on permanent hiatus for the foreseeable future. There's no official reason for the decision, though we can hazard some guesses which do have Hexpoint infringements tolement, and multiple individuals have already taken to Discord to say it isn't a good idea. Keep in mind that this article is authored by the person who actually contacted Hexpoint directly, and he contradicted the article's claims up and down in more subtle ways."
lorem_ipsum = u"Lorem ipsum dolor sit amet, consectetur adipiscing elit, sed do eiusmod tempor incididunt ut labore et dolore magna aliqua. Ut enim ad minim veniam, quis nostrud exercitation ullamco laboris nisi ut aliquip ex ea commodo consequat. Duis aute irure dolor in reprehenderit in voluptate velit esse cillum dolore eu fugiat nulla pariatur. Excepteur sint occaecat cupidatat non proident, sunt in culpa qui officia deserunt mollit anim id est laborum."
nyt = u'European Union policymakers agreed on Friday to a sweeping new law to regulate artificial intelligence, one of the world’s first comprehensive attempts to limit the use of a rapidly evolving technology that has wide-ranging societal and economic implications. The law, called the A.I. Act, sets a new global benchmark for countries seeking to harness the potential benefits of the technology, while trying to protect against its possible risks, like automating jobs, spreading misinformation online and endangering national security. The law still needs to go through a few final steps for approval, but the political agreement means its key outlines have been set.'
emma = u'Emma Woodhouse, handsome, clever, and rich, with a comfortable home and happy disposition, seemed to unite some of the best blessings of existence; and had lived nearly twenty-one years in the world with very little to distress or vex her. She was the youngest of the two daughters of a most affectionate, indulgent father; and had, in consequence of her sister’s marriage, been mistress of his house from a very early period. Her mother had died too long ago for her to have more than an indistinct remembrance of her caresses; and her place had been supplied by an excellent woman as governess, who had fallen little short of a mother in affection. Sixteen years had Miss Taylor been in Mr. Woodhouse’s family, less as a governess than a friend, very fond of both daughters, but particularly of Emma. Between them it was more the intimacy of sisters. Even before Miss Taylor had ceased to hold the nominal office of governess, the mildness of her temper had hardly allowed her to impose any restraint; and the shadow of authority being now long passed away, they had been living together as friend and friend very mutually attached, and Emma doing just what she liked; highly esteeming Miss Taylor’s judgment, but directed chiefly by her own.'
human_h3 = u"""Basically there are many categories of " Best Seller " . Replace " Best Seller " by something like " Oscars " and every " best seller " book is basically an " oscar - winning " book . May not have won the " Best film " , but even if you won the best director or best script , you 're still an " oscar - winning " film . Same thing for best sellers . Also , IIRC the rankings change every week or something like that . Some you might not be best seller one week , but you may be the next week . I guess even if you do n't stay there for long , you still achieved the status . Hence , # 1 best seller ."""
machine_h3 = u"""There are many different best seller lists that are published by various organizations, and the New York Times is just one of them. The New York Times best seller list is a weekly list that ranks the best-selling books in the United States based on sales data from a number of different retailers. The list is published in the New York Times newspaper and is widely considered to be one of the most influential best seller lists in the book industry.  It's important to note that the New York Times best seller list is not the only best seller list out there, and there are many other lists that rank the top-selling books in different categories or in different countries. So it's possible that a book could be a best seller on one list but not on another. Additionally, the term "best seller" is often used more broadly to refer to any book that is selling well, regardless of whether it is on a specific best seller list or not. So it's possible that you may hear about a book being a "best seller" even if it is not specifically ranked as a number one best seller on the New York Times list or any other list."""

# %%
from detectgpt.detector_detectgpt import DetectorDetectGPT
from gpt2outputdataset.detector_radford import DetectorRadford

# %%
detector_detectgpt = DetectorDetectGPT()
#detector_radford = DetectorRadford()
# Out:
# Using cache dir ./.cache
# Loading BASE model EleutherAI/pythia-70m...
# Loading mask filling model t5-small...
# MOVING BASE MODEL TO GPU...DONE (1.87s)
# Initialized

# %%
detector_detectgpt.predict_proba_machine([machine_h3])
# Out:
# texts predict proba ['There are many different best seller lists that are published by various organizations, and the New York Times is just one of them. The New York Times best seller list is a weekly list that ranks the best-selling books in the United States based on sales data from a number of different retailers. The list is published in the New York Times newspaper and is widely considered to be one of the most influential best seller lists in the book industry.  It\'s important to note that the New York Times best seller list is not the only best seller list out there, and there are many other lists that rank the top-selling books in different categories or in different countries. So it\'s possible that a book could be a best seller on one list but not on another. Additionally, the term "best seller" is often used more broadly to refer to any book that is selling well, regardless of whether it is on a specific best seller list or not. So it\'s possible that you may hear about a book being a "best seller" even if it is not specifically ranked as a number one best seller on the New York Times list or any other list.']
# MOVING MASK MODEL TO GPU...DONE (0.12s)
# Applying perturbations: 0it [00:00, ?it/s]
# Applying perturbations: 100%|██████████| 1/1 [00:01<00:00,  1.85s/it]
# MOVING BASE MODEL TO GPU...DONE (0.09s)
# Computing log likelihoods: 100%|██████████| 1/1 [00:00<00:00,  5.05it/s]
# [[1 0]]
# array([1.])

# %%
detector_detectgpt.predict_proba_machine([machine_h3,machine_h3,machine_h3])
# Out:
# texts predict proba ['There are many different best seller lists that are published by various organizations, and the New York Times is just one of them. The New York Times best seller list is a weekly list that ranks the best-selling books in the United States based on sales data from a number of different retailers. The list is published in the New York Times newspaper and is widely considered to be one of the most influential best seller lists in the book industry.  It\'s important to note that the New York Times best seller list is not the only best seller list out there, and there are many other lists that rank the top-selling books in different categories or in different countries. So it\'s possible that a book could be a best seller on one list but not on another. Additionally, the term "best seller" is often used more broadly to refer to any book that is selling well, regardless of whether it is on a specific best seller list or not. So it\'s possible that you may hear about a book being a "best seller" even if it is not specifically ranked as a number one best seller on the New York Times list or any other list.', 'There are many different best seller lists that are published by various organizations, and the New York Times is just one of them. The New York Times best seller list is a weekly list that ranks the best-selling books in the United States based on sales data from a number of different retailers. The list is published in the New York Times newspaper and is widely considered to be one of the most influential best seller lists in the book industry.  It\'s important to note that the New York Times best seller list is not the only best seller list out there, and there are many other lists that rank the top-selling books in different categories or in different countries. So it\'s possible that a book could be a best seller on one list but not on another. Additionally, the term "best seller" is often used more broadly to refer to any book that is selling well, regardless of whether it is on a specific best seller list or not. So it\'s possible that you may hear about a book being a "best seller" even if it is not specifically ranked as a number one best seller on the New York Times list or any other list.', 'There are many different best seller lists that are published by various organizations, and the New York Times is just one of them. The New York Times best seller list is a weekly list that ranks the best-selling books in the United States based on sales data from a number of different retailers. The list is published in the New York Times newspaper and is widely considered to be one of the most influential best seller lists in the book industry.  It\'s important to note that the New York Times best seller list is not the only best seller list out there, and there are many other lists that rank the top-selling books in different categories or in different countries. So it\'s possible that a book could be a best seller on one list but not on another. Additionally, the term "best seller" is often used more broadly to refer to any book that is selling well, regardless of whether it is on a specific best seller list or not. So it\'s possible that you may hear about a book being a "best seller" even if it is not specifically ranked as a number one best seller on the New York Times list or any other list.']
# MOVING MASK MODEL TO GPU...DONE (0.13s)
# Applying perturbations: 0it [00:00, ?it/s]
# Applying perturbations: 100%|██████████| 2/2 [00:02<00:00,  1.34s/it]
# MOVING BASE MODEL TO GPU...DONE (0.11s)
# Computing log likelihoods: 100%|██████████| 3/3 [00:00<00:00,  5.28it/s]
# [[1 0]
#  [1 0]
#  [1 0]]
# array([1., 1., 1.])

# %%
detector_detectgpt.predict_proba_machine([machine_h3,machine_h3,machine_h3])
# Out:
# texts predict proba ['There are many different best seller lists that are published by various organizations, and the New York Times is just one of them. The New York Times best seller list is a weekly list that ranks the best-selling books in the United States based on sales data from a number of different retailers. The list is published in the New York Times newspaper and is widely considered to be one of the most influential best seller lists in the book industry.  It\'s important to note that the New York Times best seller list is not the only best seller list out there, and there are many other lists that rank the top-selling books in different categories or in different countries. So it\'s possible that a book could be a best seller on one list but not on another. Additionally, the term "best seller" is often used more broadly to refer to any book that is selling well, regardless of whether it is on a specific best seller list or not. So it\'s possible that you may hear about a book being a "best seller" even if it is not specifically ranked as a number one best seller on the New York Times list or any other list.', 'There are many different best seller lists that are published by various organizations, and the New York Times is just one of them. The New York Times best seller list is a weekly list that ranks the best-selling books in the United States based on sales data from a number of different retailers. The list is published in the New York Times newspaper and is widely considered to be one of the most influential best seller lists in the book industry.  It\'s important to note that the New York Times best seller list is not the only best seller list out there, and there are many other lists that rank the top-selling books in different categories or in different countries. So it\'s possible that a book could be a best seller on one list but not on another. Additionally, the term "best seller" is often used more broadly to refer to any book that is selling well, regardless of whether it is on a specific best seller list or not. So it\'s possible that you may hear about a book being a "best seller" even if it is not specifically ranked as a number one best seller on the New York Times list or any other list.', 'There are many different best seller lists that are published by various organizations, and the New York Times is just one of them. The New York Times best seller list is a weekly list that ranks the best-selling books in the United States based on sales data from a number of different retailers. The list is published in the New York Times newspaper and is widely considered to be one of the most influential best seller lists in the book industry.  It\'s important to note that the New York Times best seller list is not the only best seller list out there, and there are many other lists that rank the top-selling books in different categories or in different countries. So it\'s possible that a book could be a best seller on one list but not on another. Additionally, the term "best seller" is often used more broadly to refer to any book that is selling well, regardless of whether it is on a specific best seller list or not. So it\'s possible that you may hear about a book being a "best seller" even if it is not specifically ranked as a number one best seller on the New York Times list or any other list.']
# MOVING MASK MODEL TO GPU...DONE (0.12s)
# Applying perturbations: 0it [00:00, ?it/s]
# Applying perturbations: 100%|██████████| 2/2 [00:02<00:00,  1.36s/it]
# MOVING BASE MODEL TO GPU...DONE (0.11s)
# Computing log likelihoods: 100%|██████████| 3/3 [00:00<00:00,  4.61it/s]
# [[1 0]
#  [1 0]
#  [1 0]]
# array([1., 1., 1.])

# %%
detector_detectgpt.predict_proba([machine_h3])
# Out:
# texts predict proba ['There are many different best seller lists that are published by various organizations, and the New York Times is just one of them. The New York Times best seller list is a weekly list that ranks the best-selling books in the United States based on sales data from a number of different retailers. The list is published in the New York Times newspaper and is widely considered to be one of the most influential best seller lists in the book industry.  It\'s important to note that the New York Times best seller list is not the only best seller list out there, and there are many other lists that rank the top-selling books in different categories or in different countries. So it\'s possible that a book could be a best seller on one list but not on another. Additionally, the term "best seller" is often used more broadly to refer to any book that is selling well, regardless of whether it is on a specific best seller list or not. So it\'s possible that you may hear about a book being a "best seller" even if it is not specifically ranked as a number one best seller on the New York Times list or any other list.']
# MOVING MASK MODEL TO GPU...DONE (0.12s)
# Applying perturbations: 0it [00:00, ?it/s]
# Applying perturbations: 100%|██████████| 1/1 [00:01<00:00,  1.37s/it]
# MOVING BASE MODEL TO GPU...DONE (0.11s)
# Computing log likelihoods: 100%|██████████| 1/1 [00:00<00:00,  5.02it/s]
# [[1 0]]
# array([[1, 0]])

# %%
# detector_detectgpt.predict_proba(['<<<mask>>>'])

# %%
# detector_radford = DetectorRadford()

# %%
# detector_radford.predict_proba([machine_h3])

# %%
import shap
import transformers
import numpy as np

# %%
tokenizer = transformers.DistilBertTokenizerFast.from_pretrained(
    "distilbert-base-uncased"
) # example from https://shap.readthedocs.io/en/latest/example_notebooks/api_examples/plots/text.html

# %%
masker = shap.maskers.Text(tokenizer, mask_token=detector_detectgpt.get_mask_token())
explainer = shap.Explainer(detector_detectgpt.predict_proba_machine, tokenizer=tokenizer, masker=masker)

# %%
text = '<|endoftext|>So it\'s possible that you may hear about a book being a "best seller" even if it is not specifically ranked as a number one best seller on the New York Times list or any other list.'

# %%
detector_detectgpt.predict_proba_machine(["Test 1234 Loris"])
# Out:
# texts predict proba ['Test 1234 Loris']
# MOVING MASK MODEL TO GPU...DONE (0.13s)
# Applying perturbations: 0it [00:00, ?it/s]
# Applying perturbations: 100%|██████████| 1/1 [00:02<00:00,  2.75s/it]
# MOVING BASE MODEL TO GPU...DONE (0.11s)
# Computing log likelihoods: 100%|██████████| 1/1 [00:00<00:00,  6.85it/s]
# WARNING: std of perturbed original is 0, setting to 1
# Number of unique perturbed original texts: 1
# Original text: Test 1234 Loris
# [[0 1]]
# array([0.])

# %%
# TODO zero rows shap_values = explainer(["Test 1234 Loris"])
shap_values = explainer(["Test 1234 Loris"])
# Out:
# texts predict proba ['<|endoftext|>']
# MOVING MASK MODEL TO GPU...DONE (0.12s)
# Applying perturbations: 0it [00:00, ?it/s]
# Applying perturbations: 100%|██████████| 1/1 [00:02<00:00,  2.65s/it]
# MOVING BASE MODEL TO GPU...DONE (0.10s)
# Computing log likelihoods: 100%|██████████| 1/1 [00:00<00:00,  6.06it/s]
# [[0 0]]
# texts predict proba ['Test 1234 Loris']
# MOVING MASK MODEL TO GPU...DONE (0.11s)
# Applying perturbations: 0it [00:00, ?it/s]
# Applying perturbations: 100%|██████████| 1/1 [00:02<00:00,  2.64s/it]
# MOVING BASE MODEL TO GPU...DONE (0.12s)
# Computing log likelihoods: 100%|██████████| 1/1 [00:00<00:00,  6.37it/s]
# WARNING: std of perturbed original is 0, setting to 1
# Number of unique perturbed original texts: 1
# Original text: Test 1234 Loris
# [[0 1]]
# texts predict proba ['Test 1234 <|endoftext|>' '<|endoftext|>Loris']
# MOVING MASK MODEL TO GPU...DONE (0.12s)
# Applying perturbations: 0it [00:00, ?it/s]
# Applying perturbations: 100%|██████████| 1/1 [00:02<00:00,  2.95s/it]
# MOVING BASE MODEL TO GPU...DONE (0.13s)
# Computing log likelihoods: 100%|██████████| 2/2 [00:00<00:00,  6.34it/s]
# WARNING: std of perturbed original is 0, setting to 1
# Number of unique perturbed original texts: 1
# Original text: Test 1234 <|endoftext|>
# WARNING: std of perturbed original is 0, setting to 1
# Number of unique perturbed original texts: 1
# Original text: <|endoftext|>Loris
# [[0 1]
#  [0 1]]
# texts predict proba ['<|endoftext|>Loris' '<|endoftext|>' 'Test <|endoftext|>Loris'
#  '<|endoftext|>1234 Loris' 'Test <|endoftext|>'
#  '<|endoftext|>1234 <|endoftext|>']
# MOVING MASK MODEL TO GPU...DONE (0.12s)
# Applying perturbations: 0it [00:00, ?it/s]
# Applying perturbations: 100%|██████████| 3/3 [00:08<00:00,  2.69s/it]
# MOVING BASE MODEL TO GPU...DONE (0.13s)
# Computing log likelihoods: 100%|██████████| 6/6 [00:00<00:00,  6.95it/s]
# WARNING: std of perturbed original is 0, setting to 1
# Number of unique perturbed original texts: 1
# Original text: <|endoftext|>Loris
# WARNING: std of perturbed original is 0, setting to 1
# Number of unique perturbed original texts: 1
# Original text: Test <|endoftext|>Loris
# WARNING: std of perturbed original is 0, setting to 1
# Number of unique perturbed original texts: 1
# Original text: <|endoftext|>1234 Loris
# WARNING: std of perturbed original is 0, setting to 1
# Number of unique perturbed original texts: 1
# Original text: Test <|endoftext|>
# WARNING: std of perturbed original is 0, setting to 1
# Number of unique perturbed original texts: 1
# Original text: <|endoftext|>1234 <|endoftext|>
# [[0 1]
#  [0 0]
#  [0 1]
#  [0 1]
#  [0 1]
#  [0 1]]
#   0%|          | 0/42 [00:00<?, ?it/s]
# texts predict proba ['<|endoftext|>123 <|endoftext|>Loris' '<|endoftext|>4 Loris'
#  'Test 123 <|endoftext|>Loris' 'Test <|endoftext|>4 Loris' '<|endoftext|>'
#  'Test <|endoftext|>']
# MOVING MASK MODEL TO GPU...DONE (0.13s)
# Applying perturbations: 0it [00:00, ?it/s]
#
# Applying perturbations:   0%|          | 0/3 [00:00<?, ?it/s]
# Applying perturbations:  33%|███▎      | 1/3 [00:02<00:05,  2.74s/it]
# Applying perturbations:  67%|██████▋   | 2/3 [00:05<00:02,  2.75s/it]
# Applying perturbations: 100%|██████████| 3/3 [00:08<00:00,  2.79s/it]
# MOVING BASE MODEL TO GPU...DONE (0.12s)
# Computing log likelihoods:   0%|          | 0/6 [00:00<?, ?it/s]
# Computing log likelihoods:  17%|█▋        | 1/6 [00:00<00:00,  6.15it/s]
# Computing log likelihoods:  33%|███▎      | 2/6 [00:00<00:00,  6.65it/s]
# Computing log likelihoods:  50%|█████     | 3/6 [00:00<00:00,  6.79it/s]
# Computing log likelihoods:  67%|██████▋   | 4/6 [00:00<00:00,  6.80it/s]
# Computing log likelihoods:  83%|████████▎ | 5/6 [00:00<00:00,  6.75it/s]
# Computing log likelihoods: 100%|██████████| 6/6 [00:00<00:00,  6.57it/s]
# WARNING: std of perturbed original is 0, setting to 1
# Number of unique perturbed original texts: 1
# Original text: <|endoftext|>123 <|endoftext|>Loris
# WARNING: std of perturbed original is 0, setting to 1
# Number of unique perturbed original texts: 1
# Original text: <|endoftext|>4 Loris
# WARNING: std of perturbed original is 0, setting to 1
# Number of unique perturbed original texts: 1
# Original text: Test 123 <|endoftext|>Loris
# WARNING: std of perturbed original is 0, setting to 1
# Number of unique perturbed original texts: 1
# Original text: Test <|endoftext|>4 Loris
# WARNING: std of perturbed original is 0, setting to 1
# Number of unique perturbed original texts: 1
# Original text: Test <|endoftext|>
# [[0 1]
#  [0 1]
#  [0 1]
#  [0 1]
#  [0 0]
#  [0 1]]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 shap_values = explainer(["Test 1234 Loris"])
#
# File c:\Users\loris\thesis\.venv\Lib\site-packages\shap\explainers\_partition.py:111, in PartitionExplainer.__init__.<locals>.PartitionExplainer.__call__(self, max_evals, fixed_context, main_effects, error_bounds, batch_size, outputs, silent, *args)
#     109 def __call__(self, *args, max_evals=500, fixed_context=None, main_effects=False, error_bounds=False, batch_size="auto",
#     110              outputs=None, silent=False):
# --> 111     return super().__call__(
#     112         *args, max_evals=max_evals, fixed_context=fixed_context, main_effects=main_effects, error_bounds=error_bounds,
#     113         batch_size=batch_size, outputs=outputs, silent=silent
#     114     )
#
# File c:\Users\loris\thesis\.venv\Lib\site-packages\shap\explainers\_partition.py:125, in PartitionExplainer.__call__(self, max_evals, fixed_context, main_effects, error_bounds, batch_size, outputs, silent, *args)
#     121 def __call__(self, *args, max_evals=500, fixed_context=None, main_effects=False, error_bounds=False, batch_size="auto",
#     122              outputs=None, silent=False):
#     123     """ Explain the output of the model on the given arguments.
#     124     """
# --> 125     return super().__call__(
#     126         *args, max_evals=max_evals, fixed_context=fixed_context, main_effects=main_effects, error_bounds=error_bounds, batch_size=batch_size,
#     127         outputs=outputs, silent=silent
#     128     )
#
# File c:\Users\loris\thesis\.venv\Lib\site-packages\shap\explainers\_explainer.py:267, in Explainer.__call__(self, max_evals, main_effects, error_bounds, batch_size, outputs, silent, *args, **kwargs)
#     265     feature_names = [[] for _ in range(len(args))]
#     266 for row_args in show_progress(zip(*args), num_rows, self.__class__.__name__+" explainer", silent):
# --> 267     row_result = self.explain_row(
#     268         *row_args, max_evals=max_evals, main_effects=main_effects, error_bounds=error_bounds,
#     269         batch_size=batch_size, outputs=outputs, silent=silent, **kwargs
#     270     )
#     271     values.append(row_result.get("values", None))
#     272     output_indices.append(row_result.get("output_indices", None))
#
# File c:\Users\loris\thesis\.venv\Lib\site-packages\shap\explainers\_partition.py:173, in PartitionExplainer.explain_row(self, max_evals, main_effects, error_bounds, batch_size, outputs, silent, fixed_context, *row_args)
#     170 self.values = np.zeros(out_shape)
#     171 self.dvalues = np.zeros(out_shape)
# --> 173 self.owen(fm, self._curr_base_value, f11, max_evals - 2, outputs, fixed_context, batch_size, silent)
#     175 # if False:
#     176 #     if self.multi_output:
#     177 #         return [self.dvalues[:,i] for i in range(self.dvalues.shape[1])], oinds
#    (...)
#     180 # else:
#     181 # drop the interaction terms down onto self.values
#     182 self.values[:] = self.dvalues
#
# File c:\Users\loris\thesis\.venv\Lib\site-packages\shap\explainers\_partition.py:330, in PartitionExplainer.owen(self, fm, f00, f11, max_evals, output_indexes, fixed_context, batch_size, silent)
#     328     # recurse on the right node with zero context
#     329     args = (m00, f00, f01, rind, new_weight)
# --> 330     q.put((-np.max(np.abs(f01 - f00)) * new_weight, np.random.randn(), args))
#     332 if fixed_context is None or fixed_context == 1:
#     333     # recurse on the left node with one context
#     334     args = (m01, f01, f11, lind, new_weight)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\queue.py:150, in Queue.put(self, item, block, timeout)
#     148                 raise Full
#     149             self.not_full.wait(remaining)
# --> 150 self._put(item)
#     151 self.unfinished_tasks += 1
#     152 self.not_empty.notify()
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\queue.py:236, in PriorityQueue._put(self, item)
#     235 def _put(self, item):
# --> 236     heappush(self.queue, item)
#
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()

# %%
shap.plots.text(shap_values)
# Out:
#     <br>
#     <hr style="height: 1px; background-color: #fff; border: none; margin-top: 18px; margin-bottom: 18px; border-top: 1px dashed #ccc;"">
#     <div align="center" style="margin-top: -35px;"><div style="display: inline-block; background: #fff; padding: 5px; color: #999; font-family: monospace">[0]</div>
#     </div>
#                 <svg width="100%" height="80px"><line x1="0" y1="33" x2="100%" y2="33" style="stroke:rgb(150,150,150);stroke-width:1" /><line x1="50.042468202240734%" y1="33" x2="50.042468202240734%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="50.042468202240734%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">1</text><line x1="39.69528722679593%" y1="33" x2="39.69528722679593%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="39.69528722679593%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.9</text><line x1="29.34810625135111%" y1="33" x2="29.34810625135111%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="29.34810625135111%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.8</text><line x1="19.000925275906283%" y1="33" x2="19.000925275906283%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="19.000925275906283%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.7</text><line x1="8.653744300461463%" y1="33" x2="8.653744300461463%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="8.653744300461463%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.6</text><line x1="60.38964917768557%" y1="33" x2="60.38964917768557%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="60.38964917768557%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">1.1</text><line x1="70.73683015313037%" y1="33" x2="70.73683015313037%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="70.73683015313037%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">1.2</text><line x1="81.0840111285752%" y1="33" x2="81.0840111285752%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="81.0840111285752%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">1.3</text><line x1="91.43119210402%" y1="33" x2="91.43119210402%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="91.43119210402%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">1.4</text><line x1="49.97718626832209%" y1="33" x2="49.97718626832209%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="49.97718626832209%" y="27" font-size="13px" style="stroke:#ffffff;stroke-width:8px;" fill="rgb(255,255,255)" dominant-baseline="bottom" text-anchor="middle">0.999369</text><text x="49.97718626832209%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.999369</text><text x="49.97718626832209%" y="10" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">base value</text><line x1="50.0228126969598%" y1="33" x2="50.0228126969598%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="50.0228126969598%" y="27" font-size="13px" style="stroke:#ffffff;stroke-width:8px;" font-weight="bold" fill="rgb(255,255,255)" dominant-baseline="bottom" text-anchor="middle">0.99981</text><text x="50.0228126969598%" y="27" font-size="13px" font-weight="bold" fill="rgb(0,0,0)" dominant-baseline="bottom" text-anchor="middle">0.99981</text><text x="50.0228126969598%" y="10" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">f<tspan baseline-shift="sub" font-size="8px"></tspan>(inputs)</text><rect x="8.333333247106822%" width="41.68947944985298%" y="40" height="18" style="fill:rgb(255.0, 0.0, 81.08083606031792); stroke-width:0; stroke:rgb(0,0,0)" /><line x1="42.08547494856784%" x2="50.0228126969598%" y1="60" y2="60" id="_fb_fmdfvhiaribiulnauzfz_ind_51" style="stroke:rgb(255.0, 0.0, 81.08083606031792);stroke-width:2; opacity: 0"/><t ...
